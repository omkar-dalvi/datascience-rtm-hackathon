# %%
import pandas as pd
from eda_utils import get_null_percentage

# %%
consumer_behavior_df = pd.read_csv('../data/42fac176-29cd-40d4-bd77-3c4709063d91_consumerbehavior.csv')
products_df = pd.read_csv("../data/a72d47ec-694f-4744-8ffd-ffd875fe7d30_products.csv")
competitor_df = pd.read_csv("../data/b1e476b3-c4ea-41b6-8957-b1954434dd26_competitivelandscape.csv")
distribution_df = pd.read_csv("../data/e7486a22-3dda-40cc-a091-42c71ead2b81_retailsalesdistribution.csv")
marketing_df = pd.read_csv("../data/df7b0066-eb64-4bfd-86eb-7e54c93882e6_externalmarketinfluencers.csv")
city_df = pd.read_csv("../data/c37e916d-3656-41fe-97da-f0bc860d6711_city.csv")

# %% [markdown]
# ### Merging city_df and consumer_behavior_df

# %%
get_null_percentage(city_df)
# Out:
# City_ID                             0.0
# City_Name                           0.0
# City_tier                           0.0
# Population_Density(persons/km)      0.0
# Per_Capita_Income (INR)             0.0
# Unnamed: 5                        100.0
# Unnamed: 6                        100.0
# Unnamed: 7                        100.0
# Unnamed: 8                        100.0
# Unnamed: 9                        100.0
# Unnamed: 10                       100.0
# Unnamed: 11                       100.0
# Unnamed: 12                       100.0
# dtype: float64

# %%
# dropped empty column / unnecessary columns
city_df.drop(columns=["Unnamed: 5", "Unnamed: 6", "Unnamed: 7", "Unnamed: 8", "Unnamed: 9", "Unnamed: 10", "Unnamed: 11", "Unnamed: 12"], inplace=True)

# %%
get_null_percentage(city_df), len(city_df)
# Out:
# (City_ID                           0.0
#  City_Name                         0.0
#  City_tier                         0.0
#  Population_Density(persons/km)    0.0
#  Per_Capita_Income (INR)           0.0
#  dtype: float64,
#  20)

# %%
get_null_percentage(consumer_behavior_df), len(consumer_behavior_df)
# Out:
# (Customer_ID           0.000
#  Age_Group             0.000
#  Income_Level          0.000
#  City_ID               0.000
#  Preferred_Flavor      0.000
#  Purchase_Frequency    4.976
#  Price_Sensitivity     0.000
#  Preferred_Channel     0.000
#  Active                0.000
#  dtype: float64,
#  50000)

# %%
consumer_behavior_df[consumer_behavior_df['Purchase_Frequency'].isnull()]
# Out:
#        Customer_ID Age_Group   Income_Level City_ID Preferred_Flavor  \
# 49     cust_000050     18-25  503117.231695   CT017      Mixed Fruit
# 86     cust_000087     36-45  891863.316358   CT007      Mixed Fruit
# 93     cust_000094     46-55  151474.652644   CT019      Mixed Fruit
# 127    cust_000128     46-55  164625.361879   CT003           Orange
# 134    cust_000135     18-25   87430.053326   CT010            Apple
# ...            ...       ...            ...     ...              ...
# 49881  cust_049882       55+  184569.895496   CT016            Guava
# 49907  cust_049908     46-55  180924.727277   CT003            Apple
# 49947  cust_049948     18-25   88678.249637   CT014      Mixed Fruit
# 49951  cust_049952     36-45  725479.425574   CT012      Mixed Fruit
# 49997  cust_049998     18-25  588522.989992   CT006      Mixed Fruit
#
#        Purchase_Frequency Price_Sensitivity Preferred_Channel  Active
# 49                    NaN               Low        E-commerce   False
# 86                    NaN               Low      Modern Trade   False
# 93                    NaN              High      Modern Trade    True
# 127                   NaN               Low     General Trade   False
# 134                   NaN            Medium        E-commerce   False
# ...                   ...               ...               ...     ...
# 49881                 NaN               Low     General Trade    True
# 49907                 NaN              High     General Trade    True
# 49947                 NaN            Medium        Q-commerce    True
# 49951                 NaN               Low        Q-commerce   False
# 49997                 NaN               Low        Q-commerce   False
#
# [2488 rows x 9 columns]

# %%
consumer_df = pd.merge(consumer_behavior_df, city_df, on="City_ID", how="left")

# %%
get_null_percentage(consumer_df), len(consumer_df)
# Out:
# (Customer_ID                       0.000
#  Age_Group                         0.000
#  Income_Level                      0.000
#  City_ID                           0.000
#  Preferred_Flavor                  0.000
#  Purchase_Frequency                4.976
#  Price_Sensitivity                 0.000
#  Preferred_Channel                 0.000
#  Active                            0.000
#  City_Name                         0.000
#  City_tier                         0.000
#  Population_Density(persons/km)    0.000
#  Per_Capita_Income (INR)           0.000
#  dtype: float64,
#  50000)

# %%
consumer_df.to_csv("../intermediate_data/consumer_city.csv", index=False)

# %% [markdown]
# ### Merging city_df and marketing_df

# %%
get_null_percentage(marketing_df), len(marketing_df)
# Out:
# (Week_Start_Date     0.000000
#  City_ID             0.000000
#  Avg_Temperature     0.000000
#  Weather_Type        0.000000
#  Festival           94.285714
#  dtype: float64,
#  2100)

# %%
marketing_df['Festival'].unique()
# Out:
# array([nan, 'Pongal', 'Holi', 'Diwali'], dtype=object)

# %%
marketing_df[marketing_df['Festival'].notnull()]
# Out:
#      Week_Start_Date City_ID  Avg_Temperature Weather_Type Festival
# 20        2023-01-09   CT001             20.6         Cold   Pongal
# 21        2023-01-09   CT002             20.2         Cold   Pongal
# 22        2023-01-09   CT003             20.1         Cold   Pongal
# 23        2023-01-09   CT004             20.7         Cold   Pongal
# 24        2023-01-09   CT005             20.7         Cold   Pongal
# ...              ...     ...              ...          ...      ...
# 1915      2024-10-28   CT016             24.9         Mild   Diwali
# 1916      2024-10-28   CT017             24.9         Mild   Diwali
# 1917      2024-10-28   CT018             26.3         Mild   Diwali
# 1918      2024-10-28   CT019             25.5         Mild   Diwali
# 1919      2024-10-28   CT020             25.9         Mild   Diwali
#
# [120 rows x 5 columns]

# %%
city_marketing_df = pd.merge(marketing_df, city_df, on="City_ID", how="left")

# %%
city_marketing_df
# Out:
#      Week_Start_Date City_ID  Avg_Temperature Weather_Type Festival  \
# 0         2023-01-02   CT001             21.0         Cold      NaN
# 1         2023-01-02   CT002             19.4         Cold      NaN
# 2         2023-01-02   CT003             19.8         Cold      NaN
# 3         2023-01-02   CT004             20.8         Cold      NaN
# 4         2023-01-02   CT005             21.6         Cold      NaN
# ...              ...     ...              ...          ...      ...
# 2095      2024-12-30   CT016             19.6         Cold      NaN
# 2096      2024-12-30   CT017             20.3         Cold      NaN
# 2097      2024-12-30   CT018             18.7         Cold      NaN
# 2098      2024-12-30   CT019             19.3         Cold      NaN
# 2099      2024-12-30   CT020             18.4         Cold      NaN
#
#       City_Name City_tier  Population_Density(persons/km)  \
# 0         Delhi    Tier 1                           14893
# 1        Mumbai    Tier 1                           20518
# 2       Kolkata    Tier 1                           24252
# 3       Chennai    Tier 1                           14456
# 4     Bengaluru    Tier 1                            4378
# ...         ...       ...                             ...
# 2095     Nagpur    Tier 2                            9664
# 2096      Surat    Tier 2                            8617
# 2097      Patna    Tier 2                            2805
# 2098   Ludhiana    Tier 2                            9750
# 2099      Jammu    Tier 2                            3571
#
#      Per_Capita_Income (INR)
# 0                   4,61,910
# 1                   4,00,000
# 2                     171184
# 3                     585501
# 4                     352000
# ...                      ...
# 2095                  296607
# 2096                  389810
# 2097                  173305
# 2098                  123882
# 2099                  186000
#
# [2100 rows x 9 columns]

# %%
get_null_percentage(city_marketing_df), len(city_marketing_df)
# Out:
# (Week_Start_Date                    0.000000
#  City_ID                            0.000000
#  Avg_Temperature                    0.000000
#  Weather_Type                       0.000000
#  Festival                          94.285714
#  City_Name                          0.000000
#  City_tier                          0.000000
#  Population_Density(persons/km)     0.000000
#  Per_Capita_Income (INR)            0.000000
#  dtype: float64,
#  2100)

# %%
city_marketing_df.to_csv("../intermediate_data/marketing_city.csv", index=False)

# %% [markdown]
# ### Merging retail sales with products and city data

# %%
products_df.rename(columns={"SKU Identification Number": "SKU_ID"}, inplace=True)

get_null_percentage(products_df), len(products_df)
# Out:
# (Product Name                0.0
#  Flavor Variant              0.0
#  SKU_ID                      0.0
#  Launch Date (MM/DD/YYYY)    0.0
#  Pack Size (ml/L)            0.0
#  Distribution Coverage       0.0
#  dtype: float64,
#  7)

# %%
get_null_percentage(distribution_df), len(distribution_df)
# Out:
# (Date          0.0
#  City_ID       0.0
#  SKU_ID        0.0
#  Channel       0.0
#  Units_Sold    0.0
#  Sales         0.0
#  dtype: float64,
#  334300)

# %%
product_retail_sales_df = pd.merge(pd.merge(distribution_df, products_df, on="SKU_ID", how="left"), city_df, on="City_ID", how="left")

# %%
product_retail_sales_df
# Out:
#               Date City_ID   SKU_ID        Channel  Units_Sold    Sales  \
# 0       2023-01-01   CT001  SKU1002     Q Commerce         268     80.4
# 1       2023-01-01   CT001  SKU1004     Q Commerce         168     50.4
# 2       2023-01-01   CT001  SKU1001     E Commerce         521    156.3
# 3       2023-01-01   CT001  SKU1002     E Commerce         247     74.1
# 4       2023-01-01   CT001  SKU1007     E Commerce         161  12075.0
# ...            ...     ...      ...            ...         ...      ...
# 334295  2024-12-31   CT020  SKU1008  General Trade         179  13425.0
# 334296  2024-12-31   CT020  SKU1002         HoReCa         144     43.2
# 334297  2024-12-31   CT020  SKU1007         HoReCa         123   9225.0
# 334298  2024-12-31   CT020  SKU1004         HoReCa          44     13.2
# 334299  2024-12-31   CT020  SKU1008         HoReCa          22   1650.0
#
#                                    Product Name Flavor Variant  \
# 0                 Minute Maid Mixed Fruit Juice    Mixed Fruit
# 1                      Minute Maid Pulpy Orange         Orange
# 2       Minute Maid Apple Juice - Honey Infused          Apple
# 3                 Minute Maid Mixed Fruit Juice    Mixed Fruit
# 4                Minute Maid 250ml Pulpy Orange         Orange
# ...                                         ...            ...
# 334295      Minute Maid 250ml Mixed Fruit Juice    Mixed Fruit
# 334296            Minute Maid Mixed Fruit Juice    Mixed Fruit
# 334297           Minute Maid 250ml Pulpy Orange         Orange
# 334298                 Minute Maid Pulpy Orange         Orange
# 334299      Minute Maid 250ml Mixed Fruit Juice    Mixed Fruit
#
#        Launch Date (MM/DD/YYYY) Pack Size (ml/L)  \
# 0                    04/23/2015             1 L
# 1                    04/23/2015             1 L
# 2                    02/19/2022              1 L
# 3                    04/23/2015             1 L
# 4                    04/23/2015    250 ml Bottle
# ...                         ...              ...
# 334295               04/23/2015    250 ml Bottle
# 334296               04/23/2015             1 L
# 334297               04/23/2015    250 ml Bottle
# 334298               04/23/2015             1 L
# 334299               04/23/2015    250 ml Bottle
#
#                                     Distribution Coverage City_Name City_tier  \
# 0       General Trade-Retail; E-commerce; Q-Commerce; ...     Delhi    Tier 1
# 1       General Trade-Retail; E-commerce; Q-Commerce; ...     Delhi    Tier 1
# 2                        General Trade-Retail; E-commerce     Delhi    Tier 1
# 3       General Trade-Retail; E-commerce; Q-Commerce; ...     Delhi    Tier 1
# 4       General Trade-Retail; E-commerce; HoReCa; Mode...     Delhi    Tier 1
# ...                                                   ...       ...       ...
# 334295  General Trade-Retail; E-commerce; HoReCa; Mode...     Jammu    Tier 2
# 334296  General Trade-Retail; E-commerce; Q-Commerce; ...     Jammu    Tier 2
# 334297  General Trade-Retail; E-commerce; HoReCa; Mode...     Jammu    Tier 2
# 334298  General Trade-Retail; E-commerce; Q-Commerce; ...     Jammu    Tier 2
# 334299  General Trade-Retail; E-commerce; HoReCa; Mode...     Jammu    Tier 2
#
#         Population_Density(persons/km) Per_Capita_Income (INR)
# 0                                14893                4,61,910
# 1                                14893                4,61,910
# 2                                14893                4,61,910
# 3                                14893                4,61,910
# 4                                14893                4,61,910
# ...                                ...                     ...
# 334295                            3571                  186000
# 334296                            3571                  186000
# 334297                            3571                  186000
# 334298                            3571                  186000
# 334299                            3571                  186000
#
# [334300 rows x 15 columns]

# %%
get_null_percentage(product_retail_sales_df), len(product_retail_sales_df)
# Out:
# (Date                              0.0
#  City_ID                           0.0
#  SKU_ID                            0.0
#  Channel                           0.0
#  Units_Sold                        0.0
#  Sales                             0.0
#  Product Name                      0.0
#  Flavor Variant                    0.0
#  Launch Date (MM/DD/YYYY)          0.0
#  Pack Size (ml/L)                  0.0
#  Distribution Coverage             0.0
#  City_Name                         0.0
#  City_tier                         0.0
#  Population_Density(persons/km)    0.0
#  Per_Capita_Income (INR)           0.0
#  dtype: float64,
#  334300)

# %%
product_retail_sales_df.to_csv("../intermediate_data/retail_sales_city_product.csv", index=False)

# %% [markdown]
# ### Exploring competitive data

# %%
get_null_percentage(competitor_df), len(competitor_df)
# Out:
# (Date               0.0
#  Channel            0.0
#  Brand              0.0
#  Mentions_Count     0.0
#  Sentiment_Score    0.0
#  Share_of_Voice     0.0
#  dtype: float64,
#  1260)

# %%
competitor_df
# Out:
#             Date        Channel             Brand  Mentions_Count  \
# 0     2023-01-02     E Commerce     Amazon Solimo             156
# 1     2023-01-02     E Commerce       Minute Maid             346
# 2     2023-01-02     E Commerce  Real Fruit Juice             542
# 3     2023-01-02  General Trade       Minute Maid             551
# 4     2023-01-02  General Trade        Paper Boat             474
# ...          ...            ...               ...             ...
# 1255  2024-12-30         HoReCa        Paper Boat             232
# 1256  2024-12-30   Modern Trade         B Natural             247
# 1257  2024-12-30   Modern Trade       Minute Maid             359
# 1258  2024-12-30     Q Commerce       Minute Maid             430
# 1259  2024-12-30     Q Commerce         Tropicana             721
#
#       Sentiment_Score  Share_of_Voice
# 0                61.3            15.0
# 1                70.0            33.2
# 2                70.9            51.9
# 3                72.4            53.8
# 4                67.0            46.2
# ...               ...             ...
# 1255             65.3            31.6
# 1256             69.8            40.8
# 1257             69.4            59.2
# 1258             60.5            37.4
# 1259             76.9            62.6
#
# [1260 rows x 6 columns]

# %%
competitor_df.describe()
# Out:
#        Mentions_Count  Sentiment_Score  Share_of_Voice
# count     1260.000000      1260.000000     1260.000000
# mean       409.838889        70.063571       41.667302
# std        207.061264         5.547975       12.816972
# min        101.000000        50.100000       13.400000
# 25%        255.000000        66.600000       31.100000
# 50%        367.000000        70.100000       40.100000
# 75%        521.250000        73.800000       51.700000
# max       1575.000000        86.100000       67.600000
