# %%
import pandas as pd

# %%
consumer_df = pd.read_csv("../../data/intermediate_data/consumer_city.csv")
marketing_df = pd.read_csv("../../data/intermediate_data/marketing_city.csv")
sales_df = pd.read_csv("../../data/intermediate_data/retail_sales_city_product.csv")
competitor_df = pd.read_csv("../../data/processed/competitors_processed.csv")

# %%
consumer_df.columns, marketing_df.columns, sales_df.columns, competitor_df.columns
# Out:
# (Index(['Customer_ID', 'Age_Group', 'Income_Level', 'City_ID',
#         'Preferred_Flavor', 'Purchase_Frequency', 'Price_Sensitivity',
#         'Preferred_Channel', 'Active', 'City_Name', 'City_tier',
#         'Population_Density(persons/km)', 'Per_Capita_Income (INR)'],
#        dtype='object'),
#  Index(['Week_Start_Date', 'City_ID', 'Avg_Temperature', 'Weather_Type',
#         'Festival', 'City_Name', 'City_tier', 'Population_Density(persons/km)',
#         'Per_Capita_Income (INR)'],
#        dtype='object'),
#  Index(['Date', 'City_ID', 'SKU_ID', 'Channel', 'Units_Sold', 'Sales',
#         'Product Name', 'Flavor Variant', 'Launch Date', 'Pack Size (L)',
#         'General Trade', 'E Commerce', 'Modern Trade', 'HoReCa', 'Q Commerce',
#         'City_Name', 'City_tier', 'Population_Density(persons/km)',
#         'Per_Capita_Income (INR)'],
#        dtype='object'),
#  Index(['Date', 'Channel', 'Brand', 'Mentions_Count', 'Sentiment_Score',
#         'Share_of_Voice'],
# ...

# %%
len(consumer_df), len(marketing_df), len(sales_df), len(competitor_df)
# Out:
# (50000, 2100, 334300, 1260)

# %%
marketing_df.head(21)
# Out:
#    Week_Start_Date City_ID  Avg_Temperature Weather_Type     Festival  \
# 0       2023-01-02   CT001             21.0         Cold  No Festival
# 1       2023-01-02   CT002             19.4         Cold  No Festival
# 2       2023-01-02   CT003             19.8         Cold  No Festival
# 3       2023-01-02   CT004             20.8         Cold  No Festival
# 4       2023-01-02   CT005             21.6         Cold  No Festival
# 5       2023-01-02   CT006             18.8         Cold  No Festival
# 6       2023-01-02   CT007             21.0         Cold  No Festival
# 7       2023-01-02   CT008             20.4         Cold  No Festival
# 8       2023-01-02   CT009             19.5         Cold  No Festival
# 9       2023-01-02   CT010             18.4         Cold  No Festival
# 10      2023-01-02   CT011             23.0         Mild  No Festival
# 11      2023-01-02   CT012             20.4         Cold  No Festival
# ...
